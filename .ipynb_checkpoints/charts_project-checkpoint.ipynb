# %% [markdown]
# ## Проект Дашборд конверсий

# %% [markdown]
# ### Импортируем библиотеки

# %%
import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
from dotenv import load_dotenv
import os

# %% [markdown]
# ### Смотрим на выборки датасетов

# %%
#response = requests.get('https://drive.usercontent.google.com/u/0/uc?id=1AeQz0kaSgz0lxYSDtuNm36muhy5fRCzZ&export=download')
#reg_data_csv = pd.read_csv(StringIO(response.text))
#response = requests.get('https://drive.usercontent.google.com/u/0/uc?id=1QosQQ4RRNR9rkL4t7sB707h2Uy0XfYJe&export=download')
#visits_data_csv = pd.read_csv(StringIO(response.text))

# %%
#reg_data_csv.describe

# %%
#visits_data_csv.describe

# %% [markdown]
# ### Загружаем переменные окружения

# %%
load_dotenv()
DATE_BEGIN = os.getenv('DATE_BEGIN')
DATE_END = os.getenv('DATE_END')
API_URL = os.getenv('API_URL')

# %% [markdown]
# ### Загрузка данных о регистрациях через API

# %%
response = requests.get(f'{API_URL}/registrations', params={'begin': DATE_BEGIN, 'end': DATE_END})
data = response.json()
reg_data = pd.DataFrame(data)
reg_data.head(100)
# Out:
#                datetime                               user_id  \
# 0   2023-03-01T07:40:13  2e0f6bb8-b029-4f45-a786-2b53990d37f1
# 1   2023-03-01T13:14:00  f007f97c-9d8b-48b5-af08-119bb8f6d9b6
# 2   2023-03-01T03:05:50  24ff46ae-32b3-4a74-8f27-7cf0b8f32f15
# 3   2023-03-01T00:04:47  3e9914e1-5d73-4c23-b25d-b59a3aeb2b60
# 4   2023-03-01T18:31:52  27f875fc-f8ce-4aeb-8722-0ecb283d0760
# ..                  ...                                   ...
# 95  2023-03-02T18:48:41  17bcc549-c13e-46c6-ad08-adeaccf9111b
# 96  2023-03-02T18:34:04  2c062969-a1a1-4189-8043-3574ae2b12ad
# 97  2023-03-02T02:52:30  a916ca96-06d1-4433-b744-c9b6625e559d
# 98  2023-03-02T11:04:31  77d82fd5-21f1-46fb-87d3-87101d512e76
# 99  2023-03-02T02:21:08  fd3cd16d-1fa7-4eb9-b215-79620b2b3c7f
#
#                          email platform registration_type
# 0            ebyrd@example.org      web            google
# 1     knightgerald@example.org      web             email
# ...

# %% [markdown]
# ### Загрузка данных о визитах через API

# %%
response = requests.get(f'{API_URL}/visits', params={'begin': DATE_BEGIN, 'end': DATE_END})
data = response.json()
visits_data = pd.DataFrame(data)
visits_data.head(200)
# Out:
#                                  visit_id platform  \
# 0    a9f90379-ba97-41f6-936e-5e7b50a381b2  android
# 1    b51801d6-14ba-4d24-b5c4-5310ab9a040c  android
# 2    c21cfe15-0def-4416-87f2-c32dc00969ab  android
# 3    c923227f-8929-4409-a5a2-d380da6e96b9  android
# 4    ce968ca1-76c5-4d90-b146-da0e0fce71c2  android
# ..                                    ...      ...
# 195  fe549c39-fa79-4cc3-8539-fa0f43f9300c      web
# 196  fe549c39-fa79-4cc3-8539-fa0f43f9300c      web
# 197  0333468c-54cb-4052-acfd-79d49cb255d1      web
# 198  0333468c-54cb-4052-acfd-79d49cb255d1      web
# 199  b4db9fd2-7030-45c6-9d4a-395ad5e8d9fa      web
#
#                                             user_agent             datetime
# 0    Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  2023-07-13T15:32:58
# 1    Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  2023-07-13T13:22:59
# 2    Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  2023-07-13T20:43:36
# ...

# %% [markdown]
# ### Группируем регистрации по дате и платформам

# %%
group_reg = reg_data.copy()

group_reg['datetime'] = pd.to_datetime(group_reg['datetime']).dt.date

group_reg = group_reg.groupby(['datetime', 'platform'])\
                     .size()\
                     .reset_index(name='registrations')\
                     .rename(columns={'datetime':'date_group'})

group_reg.head(100)
# Out:
#     date_group platform  registrations
# 0   2023-03-01  android             61
# 1   2023-03-01      ios             18
# 2   2023-03-01      web              8
# 3   2023-03-02  android             59
# 4   2023-03-02      ios             24
# ..         ...      ...            ...
# 95  2023-04-01      web             49
# 96  2023-04-02  android             58
# 97  2023-04-02      ios             45
# 98  2023-04-02      web             59
# 99  2023-04-03  android             83
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Группируем визиты по дате и платформам

# %%
group_visits = visits_data.copy()

group_visits['datetime'] = pd.to_datetime(group_visits['datetime']).dt.date

group_visits_filter = group_visits.sort_values('datetime').groupby('visit_id', as_index=False).last()

group_visits_filter = group_visits_filter[group_visits_filter['platform'] != 'bot'].groupby(['datetime', 'platform']) \
                                         .size() \
                                         .reset_index(name='visits') \
                                         .rename(columns={'datetime':'date_group'})

group_visits_filter.head(100)
#print(group_visits_filter['platform'].unique())
# Out:
#     date_group platform  visits
# 0   2023-03-01  android      75
# 1   2023-03-01      ios      22
# 2   2023-03-01      web     279
# 3   2023-03-02  android      67
# 4   2023-03-02      ios      31
# ..         ...      ...     ...
# 95  2023-04-01      web     765
# 96  2023-04-02  android      69
# 97  2023-04-02      ios      60
# 98  2023-04-02      web     811
# 99  2023-04-03  android      96
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Мерджим визиты и регистрации, считаем конверсии

# %%
conversion_data = pd.merge(
    group_visits_filter,
    group_reg,
    on=['date_group', 'platform'],
    how='left'
)

conversion_data['conversion'] = conversion_data['registrations'] / conversion_data['visits'] * 100

conversion_data['registrations'] = conversion_data['registrations'].fillna(0).astype(int)
conversion_data.to_json('./conversion.json')
print(conversion_data)
# Out:
#      date_group platform  visits  registrations  conversion
# 0    2023-03-01  android      75             61   81.333333
# 1    2023-03-01      ios      22             18   81.818182
# 2    2023-03-01      web     279              8    2.867384
# 3    2023-03-02  android      67             59   88.059701
# 4    2023-03-02      ios      31             24   77.419355
# ..          ...      ...     ...            ...         ...
# 547  2023-08-30      ios      66             40   60.606061
# 548  2023-08-30      web    1227             34    2.770986
# 549  2023-08-31  android      57             42   73.684211
# 550  2023-08-31      ios      50             36   72.000000
# 551  2023-08-31      web     721             46    6.380028
#
# [552 rows x 5 columns]

# %% [markdown]
# ### Загружаем расходы на рекламу с csv в папке с проектом

# %%
#response = requests.get('https://drive.usercontent.google.com/u/0/uc?id=12vCtGhJlcK_CBcs8ES3BfEPbk6OJ45Qj&export=download')
#ads_csv = pd.read_csv(StringIO(response.text))
ads_csv = pd.read_csv('./ads.csv')
ads_csv.head(10)
# Out:
# ['advanced_algorithms_series' 'virtual_reality_workshop'
#  'ui_ux_design_drive' 'women_in_tech_symposium' 'intro_to_python_course']

# %% [markdown]
# ### Мерджим визиты, регистрации и затраты

# %%
ads_data = ads_csv.copy()
ads_data['date'] = pd.to_datetime(ads_data['date']).dt.date

visits_reg = conversion_data.copy()
visits_reg = visits_reg.groupby('date_group', as_index=False)[['visits', 'registrations']].sum()
visits_reg.head()

visits_registrations_ads = pd.merge(
    visits_reg,
    ads_data,
    left_on='date_group',
    right_on='date',
    how='left'
)

visits_registrations_ads = visits_registrations_ads[['date_group', 'visits', 'registrations', 'cost', 'utm_campaign']]
visits_registrations_ads = visits_registrations_ads.fillna({'cost':0, 'utm_campaign':'none'})

visits_registrations_ads.to_json('./ads.json')
visits_registrations_ads.head()
# Out:
#    date_group  visits  registrations   cost                utm_campaign
# 0  2023-03-01     376             87  212.0  advanced_algorithms_series
# 1  2023-03-02     613            106  252.0  advanced_algorithms_series
# 2  2023-03-03     683            107  202.0  advanced_algorithms_series
# 3  2023-03-04     647            159  223.0  advanced_algorithms_series
# 4  2023-03-05     707            115  265.0  advanced_algorithms_series

# %% [markdown]
# ### Выбираем период для построения графиков

# %%
if not os.path.exists('charts'):
    os.mkdir('charts')
    
START_DATE = '2023-03-01'
END_DATE = '2023-04-30'

# %% [markdown]
# ### Строим графики для анализа

# %%
vis_reg_ads_visual = visits_registrations_ads.copy()
vis_reg_ads_visual['date_group'] = vis_reg_ads_visual['date_group'].astype(str)
vis_reg_ads_visual =  vis_reg_ads_visual[vis_reg_ads_visual['date_group'].between(START_DATE, END_DATE)]

ax = vis_reg_ads_visual.plot(
    x='date_group', 
    y='visits', 
    kind='bar', 
    figsize=(max(10, len(vis_reg_ads_visual) * 0.5), 6),  # динамический размер
    color='steelblue',  # добавляем цвет
    edgecolor='navy',   # обводка
    alpha=0.8           # прозрачность для красоты
)

ax.bar_label(ax.containers[0], # подписи значений
             padding=3, 
             fontsize=10)

ax.set_title(f'Визиты с {START_DATE} по {END_DATE}', # Название графика
             fontsize=16, 
             pad=20,  # отступ заголовка
             fontweight='bold')

# названия осей
ax.set_xlabel('Дата', fontsize=12)
ax.set_ylabel('Количество визитов', fontsize=12)

# подписи осей
ax.tick_params(axis='x', rotation=45, labelsize=10)
ax.tick_params(axis='y', labelsize=10)

# cетка для лучшей читаемости
ax.grid(axis='y', alpha=0.3, linestyle='--')

# убрали легенду
ax.legend().remove()

# Автоматическая подгонка
#plt.tight_layout()

plt.savefig('./charts/visits.png', bbox_inches='tight') # сохранение с автоматическим размером
plt.show()

# %%
df_viz = conversion_data.copy()
df_viz['date_group'] = df_viz['date_group'].astype(str)
df_viz = df_viz[df_viz['date_group'].between(START_DATE, END_DATE)]

pivot_df = df_viz.pivot_table(
          index='date_group', 
          columns='platform', 
          values='visits',
          aggfunc='sum'
      )
ax = pivot_df.plot(
    kind='bar',
    stacked=True,
    figsize=(max(10, len(pivot_df) * 0.5), 6)
)
ax.set_title(f'Визиты с {START_DATE} по {END_DATE}', # Название графика
             fontsize=16, 
             pad=20,  # отступ заголовка
             fontweight='bold')
ax.set_xlabel('Дата', fontsize=12)
ax.tick_params(axis='x', rotation=45, labelsize=10)
ax.set_ylabel('Количество визитов', fontsize=12)
plt.savefig('./charts/visits_by_platform.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### Исходя из графика видно, что визиты приходятся преимущественно на WEB платформу, превышая android и ios в несколько раз

# %%
df_viz = visits_registrations_ads.copy()
df_viz['date_group'] = df_viz['date_group'].astype(str)
df_viz = df_viz[df_viz['date_group'].between(START_DATE, END_DATE)]
ax = df_viz.plot(
    x='date_group', 
    y='registrations', 
    kind='bar', 
    figsize=(max(10, len(df_viz) * 0.5), 6),  # динамический размер
    color='steelblue',  # добавляем цвет
    edgecolor='navy',   # обводка
    alpha=0.8           # прозрачность для красоты
)
ax.bar_label(ax.containers[0], # подписи значений
             padding=3, 
             fontsize=10)
ax.set_title(f'Регистрации с {START_DATE} по {END_DATE}', # Название графика
             fontsize=16, 
             pad=20,  # отступ заголовка
             fontweight='bold')
# названия осей
ax.set_xlabel('Дата', fontsize=12)
ax.set_ylabel('Количество регистраций', fontsize=12)
# подписи осей
ax.tick_params(axis='x', rotation=45, labelsize=10)
ax.tick_params(axis='y', labelsize=10)
# 6. Сетка для лучшей читаемости
ax.grid(axis='y', alpha=0.3, linestyle='--')
# убрали легенду
ax.legend().remove()
# Автоматическая подгонка
#plt.tight_layout()
plt.savefig('./charts/registrations.png', bbox_inches='tight')
plt.show()

# %%
df_viz = conversion_data.copy()
df_viz['date_group'] = df_viz['date_group'].astype(str)
df_viz = df_viz[df_viz['date_group'].between(START_DATE, END_DATE)]

pivot_df = df_viz.pivot_table(
          index='date_group', 
          columns='platform', 
          values='registrations',
          aggfunc='sum'
      )

ax = pivot_df.plot(
    kind='bar',
    stacked=True,
    figsize=(max(10, len(pivot_df) * 0.5), 6)
)

ax.set_title(f'Регистрации с {START_DATE} по {END_DATE}', # Название графика
             fontsize=16, 
             pad=20,  # отступ заголовка
             fontweight='bold')

ax.set_xlabel('Дата', fontsize=12)
ax.tick_params(axis='x', rotation=45, labelsize=10)

ax.set_ylabel('Количество регистраций', fontsize=12)
ax.grid(axis='y', alpha=0.3, linestyle='--')

plt.savefig('./charts/registrations_by_platfom.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### На графике видно преимущество платформы indroid по регистрациям. Наименьшие регистрации пользователей на ios

# %%
df_viz = visits_registrations_ads.copy()
df_viz['date_group'] = pd.to_datetime(df_viz['date_group'])
df_viz = df_viz[df_viz['date_group'].between(START_DATE, END_DATE)] 
df_viz['conversion'] = df_viz['registrations'] / df_viz['visits'] * 100

ax = df_viz.plot(x='date_group',
                 y='conversion',
                 figsize=(max(10, len(df_viz) * 0.5), 6),
                 marker='o',
                 linewidth=1,
                 markersize=6,
                 color='green',
         )

ax.set_title(f'Конверсии с {START_DATE} по {END_DATE}', 
             fontsize=16, pad=20, fontweight='bold')

for x, y in zip(df_viz['date_group'], df_viz['conversion']): # подписи знчений
    ax.annotate(f'{y:.1f}%', 
                (x, y), 
                textcoords="offset points", 
                xytext=(0,10), 
                ha='center',
                fontsize=9)

ax.set_xlabel('Дата', fontsize=12)
ax.set_ylabel('Конверсии', fontsize=12)
ax.legend().remove()

# Форматируем ось Y в проценты
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0f}%'))

plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig('./charts/conversion.png', bbox_inches='tight')
plt.show()

# %%
df_viz = conversion_data.copy()
df_viz['date_group'] = pd.to_datetime(df_viz['date_group'])
df_viz = df_viz[df_viz['date_group'].between(START_DATE, END_DATE)] 

fig = px.line(df_viz, 
              x='date_group', 
              y='conversion',
              color='platform',
              text=df_viz['conversion'].apply(lambda x: f'{x:.0f}'),
              markers=True,
              width=1900, 
              height=500,
        )

fig.update_layout(
    yaxis_tickformat='.2f',
    xaxis_title='Дата',
    yaxis_title='Конверсии',
    title='Конверсии по платформам'
)

fig.update_traces(
    name='android',
    selector={'name':'android'},
    textposition='top center',  # позиция: top center, bottom center, top left и т.д.
    textfont=dict(size=10) 
)

fig.update_traces(
    name='ios',
    selector={'name':'ios'},
    textposition='bottom center',  # позиция: top center, bottom center, top left и т.д.
    textfont=dict(size=10) 
)
fig.update_traces(
    name='web',
    selector={'name':'web'},
    textposition='top center',  # позиция: top center, bottom center, top left и т.д.
    textfont=dict(size=10) 
)

fig.write_html('./charts/conversion_by_platform.html')
fig.show()

# %%
#### На платформе web наименьшие конверсии. Возможно рекламные компании попали не в целевую аудиторию. Тогда как с других платформ было меньше визитов, однако конверсии в среднем 75 - 85 %.

# %%
df_viz = visits_registrations_ads.copy()
df_viz['date_group'] = df_viz['date_group'].astype(str)
df_viz = df_viz[df_viz['date_group'].between(START_DATE, END_DATE)] 

fig = px.line(df_viz, 
              x='date_group', 
              y=['cost', 'visits'],
              markers=True,
              width=1900, 
              height=500,
        )

# Настраиваем подписи
fig.update_traces(
    name='Затраты',
    selector={'name': 'cost'},
    text=df_viz['cost'].apply(lambda x: f'{x:.0f} ₽'),
    textposition='top center',
    textfont=dict(size=9, color='blue'),
    mode='lines+markers+text'  # включаем отображение текста!
)

# Настраиваем подписи
fig.update_traces(
    name='Визиты',
    selector={'name': 'visits'},
    text=df_viz['visits'].apply(lambda x: f'{x:.0f}'),
    textposition='top center',
    textfont=dict(size=9, color='red'),
    mode='lines+markers+text'
)

fig.update_layout(
    yaxis_tickformat='.2f',
    xaxis_title='Дата',
    yaxis_title='',
    title='Расходы на рекламу / визиты'
)

#fig.write_image('./charts/visits_and_cost.png', width=1900, height=500, scale=1)
fig.show()

# %% [markdown]
# #### На графике видна зависимость расходов на рекламу и визитов. Сокращение расходов после 15 марта негативно сказалось на визитах, падение почти в 3 раза.

# %%
# Подготовка данных
df_visits = conversion_data.copy()
df_visits['date_group'] = pd.to_datetime(df_visits['date_group'])
df_visits = df_visits.sort_values('date_group')

# Получаем данные о рекламных кампаниях
df_ads = visits_registrations_ads.copy()
df_ads['date_group'] = pd.to_datetime(df_ads['date_group'])

# Словарь цветов для разных кампаний
campaign_colors = {
    'advanced_algorithms_series': 'rgba(183, 111, 39, 1)',  # коричневый
    'virtual_reality_workshop': 'rgba(232, 209, 186, 1)',    # бежевый
    'ui_ux_design_drive': 'rgba(159, 63, 222, 1)',           # фиолетовый
    'women_in_tech_symposium': 'rgba(122, 244, 111, 1)',     # зеленый
    'intro_to_python_course': 'rgba(147, 39, 186, 1)'        # темно-фиолетовый
}

# Функция для добавления областей кампаний с легендой
def add_campaign_areas(fig, df_ads, campaign_colors):
    added_to_legend = set()  # отслеживаем, какие кампании уже добавлены в легенду
    
    for campaign in df_ads['utm_campaign'].unique():
        if campaign != 'none':
            campaign_data = df_ads[df_ads['utm_campaign'] == campaign]
            color = campaign_colors.get(campaign, 'rgba(128, 128, 128, 0.2)')
            
            for idx, row in campaign_data.iterrows():
                show_in_legend = campaign not in added_to_legend
                
                fig.add_vrect(
                    x0=row['date_group'] - pd.Timedelta(days=0.5),
                    x1=row['date_group'] + pd.Timedelta(days=0.5),
                    fillcolor=color,
                    opacity=0.3,
                    line_width=0,
                    name=f'📢 {campaign}' if show_in_legend else None,
                    legendgroup=campaign,
                    showlegend=show_in_legend
                )
                
                if show_in_legend:
                    added_to_legend.add(campaign)

# ГРАФИК 1: Визиты с периодами рекламных кампаний
fig1 = go.Figure()

# Добавляем линии для каждой платформы
platforms = df_visits['platform'].unique()
colors = ['#636EFA', '#EF553B', '#00CC96']  # цвета для android, ios, web

for i, platform in enumerate(platforms):
    platform_data = df_visits[df_visits['platform'] == platform]
    
    fig1.add_trace(go.Scatter(
        x=platform_data['date_group'],
        y=platform_data['visits'],
        mode='lines+markers',
        name=f'📊 {platform}',
        line=dict(color=colors[i], width=2),
        marker=dict(size=6),
        hovertemplate=f'{platform}: %{{y}} визитов<br>Дата: %{{x}}<extra></extra>',
        legendgroup='visits'
    ))

# Добавляем цветные области для рекламных кампаний с легендой
add_campaign_areas(fig1, df_ads, campaign_colors)

# Настройка layout для первого графика
fig1.update_layout(
    title='Визиты по платформам с периодами рекламных кампаний',
    xaxis_title='Дата',
    yaxis_title='Количество визитов',
    hovermode='x unified',
    showlegend=True,
    height=600,
    template='plotly_white',
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.05,
        bgcolor='rgba(255, 255, 255, 0.8)',
        bordercolor='rgba(0,0,0,0.2)',
        borderwidth=1
    ),
    margin=dict(r=300)  # отступ справа для легенды
)

fig1.update_xaxes(tickangle=45, nticks=20)

# Сохраняем первый график
fig1.write_html('./charts/visits_with_campaigns_legend.html')
fig1.show()


# ГРАФИК 2: Регистрации с периодами рекламных кампаний
fig2 = go.Figure()

# Добавляем линии для каждой платформы
for i, platform in enumerate(platforms):
    platform_data = df_visits[df_visits['platform'] == platform]
    
    fig2.add_trace(go.Scatter(
        x=platform_data['date_group'],
        y=platform_data['registrations'],
        mode='lines+markers',
        name=f'📊 {platform}',
        line=dict(color=colors[i], width=2),
        marker=dict(size=6),
        hovertemplate=f'{platform}: %{{y}} регистраций<br>Дата: %{{x}}<extra></extra>',
        legendgroup='registrations'
    ))

# Добавляем цветные области для рекламных кампаний с легендой
add_campaign_areas(fig2, df_ads, campaign_colors)

# Настройка layout для второго графика
fig2.update_layout(
    title='Регистрации по платформам с периодами рекламных кампаний',
    xaxis_title='Дата',
    yaxis_title='Количество регистраций',
    hovermode='x unified',
    showlegend=True,
    height=600,
    template='plotly_white',
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.05,
        bgcolor='rgba(255, 255, 255, 0.8)',
        bordercolor='rgba(0,0,0,0.2)',
        borderwidth=1
    ),
    margin=dict(r=300)
)

fig2.update_xaxes(tickangle=45, nticks=20)

# Сохраняем второй график
fig2.write_html('./charts/registrations_with_campaigns_legend.html')
fig2.show()


# ГРАФИК 3: Суммарные визиты и регистрации
fig3 = make_subplots(specs=[[{"secondary_y": True}]])

# Суммируем по дням
daily_totals = df_visits.groupby('date_group').agg({
    'visits': 'sum',
    'registrations': 'sum'
}).reset_index()

# Добавляем суммарные визиты
fig3.add_trace(
    go.Scatter(
        x=daily_totals['date_group'],
        y=daily_totals['visits'],
        mode='lines+markers',
        name='📈 Всего визитов',
        line=dict(color='#1b3ff5', width=2),
        marker=dict(size=6),
        legendgroup='totals',
        line_shape='spline'
    ),
    secondary_y=False
)

# Добавляем суммарные регистрации
fig3.add_trace(
    go.Scatter(
        x=daily_totals['date_group'],
        y=daily_totals['registrations'],
        mode='lines+markers',
        name='📉 Всего регистраций',
        line=dict(color='#1bf555', width=2),
        marker=dict(size=6),
        legendgroup='totals',
        line_shape='spline'
    ),
    secondary_y=True
)

# Добавляем цветные области для рекламных кампаний с легендой
add_campaign_areas(fig3, df_ads, campaign_colors)

# Настройка layout для третьего графика
fig3.update_layout(
    title='Суммарные визиты и регистрации с периодами рекламных кампаний',
    xaxis_title='Дата',
    hovermode='x unified',
    showlegend=True,
    height=600,
    template='plotly_white',
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=1.05,
        bgcolor='rgba(255, 255, 255, 0.8)',
        bordercolor='rgba(0,0,0,0.2)',
        borderwidth=1
    ),
    margin=dict(r=300)
)

fig3.update_xaxes(tickangle=45, nticks=20)
fig3.update_yaxes(title_text="Количество визитов", secondary_y=False)
fig3.update_yaxes(title_text="Количество регистраций", secondary_y=True)

# Сохраняем третий график
fig3.write_html('./charts/totals_with_campaigns_legend.html')
fig3.show()

# %% [markdown]
# #### В целом все рекламные компании повлияли на количество визитов и регистрации.
# #### Наиболее успешные компании по визитам: advanced_algorithms_series, women_in_tech_symposium, intro_to_python_course
# #### Наиболее успешные компании по регистрациям:advanced_algorithms_series, virtual_reality_workshop
# #### Рекламны влияют на визиты с web, в меньшей степени с android и практически не влияют на пользователей ios

# %%
df = visits_registrations_ads.copy()
# Создаем маску для дней с рекламной кампанией (utm_campaign не равен 'none')
mask_campaign = df['utm_campaign'] != 'none'
mask_no_campaign = df['utm_campaign'] == 'none'

# Рассчитываем средние показатели
stats = pd.DataFrame({
    'Показатель': ['Визиты', 'Регистрации', 'Конверсия в регистрации (%)', 'Затраты (cost)'],
    
    'Среднее с рекламой': [
        df.loc[mask_campaign, 'visits'].mean(),
        df.loc[mask_campaign, 'registrations'].mean(),
        (df.loc[mask_campaign, 'registrations'].sum() / df.loc[mask_campaign, 'visits'].sum() * 100) if df.loc[mask_campaign, 'visits'].sum() > 0 else 0,
        df.loc[mask_campaign, 'cost'].mean()
    ],
    
    'Среднее без рекламы': [
        df.loc[mask_no_campaign, 'visits'].mean(),
        df.loc[mask_no_campaign, 'registrations'].mean(),
        (df.loc[mask_no_campaign, 'registrations'].sum() / df.loc[mask_no_campaign, 'visits'].sum() * 100) if df.loc[mask_no_campaign, 'visits'].sum() > 0 else 0,
        df.loc[mask_no_campaign, 'cost'].mean()
    ]
})

# Добавляем колонку с приростом (в абсолютных значениях)
stats['Абсолютный прирост'] = stats['Среднее с рекламой'] - stats['Среднее без рекламы']

# Добавляем колонку с приростом в процентах
stats['Относительный прирост (%)'] = (stats['Абсолютный прирост'] / stats['Среднее без рекламы'] * 100).round(1)

# Округляем значения для лучшей читаемости
stats['Среднее с рекламой'] = stats['Среднее с рекламой'].round(1)
stats['Среднее без рекламы'] = stats['Среднее без рекламы'].round(1)
stats['Абсолютный прирост'] = stats['Абсолютный прирост'].round(1)

print("Сравнение показателей в дни с рекламными кампаниями и без них:")
print("=" * 100)
print(stats.to_string(index=False))

# Дополнительная информация о количестве дней
print(f"\nКоличество дней с рекламными кампаниями: {mask_campaign.sum()}")
print(f"Количество дней без рекламных кампаний: {mask_no_campaign.sum()}")
print(f"Всего дней в датасете: {len(df)}")

# Более детальная статистика по кампаниям
print("\n" + "=" * 100)
print("Детальная статистика по каждой рекламной кампании:")
print("=" * 100)

# Группировка по конкретным кампаниям
campaign_stats = df[df['utm_campaign'] != 'none'].groupby('utm_campaign').agg({
    'visits': ['mean', 'sum', 'count'],
    'registrations': ['mean', 'sum'],
    'cost': ['mean', 'sum']
}).round(1)

# Переименовываем колонки для читаемости
campaign_stats.columns = ['Визиты (ср)', 'Визиты (всего)', 'Дней', 
                         'Регистрации (ср)', 'Регистрации (всего)',
                         'Затраты (ср)', 'Затраты (всего)']

# Добавляем конверсию
campaign_stats['Конверсия (%)'] = (campaign_stats['Регистрации (всего)'] / campaign_stats['Визиты (всего)'] * 100).round(1)

# Добавляем стоимость за визит (CPV)
campaign_stats['CPV'] = (campaign_stats['Визиты (всего)'] / campaign_stats['Регистрации (всего)']).round(2)

# Добавляем стоимость за регистрацию (CPA)
campaign_stats['CPA'] = (campaign_stats['Затраты (всего)'] / campaign_stats['Регистрации (всего)']).round(2)

# Увеличил окно вывода
pd.set_option('display.width', 1000)

print(campaign_stats.sort_values('Конверсия (%)', ascending=False))
# Out:
# Сравнение показателей в дни с рекламными кампаниями и без них:
# ...
#                  Показатель  Среднее с рекламой  Среднее без рекламы  Абсолютный прирост  Относительный прирост (%)
#                      Визиты               815.1                546.6               268.5                       49.1
#                 Регистрации               125.6                 95.3                30.2                       31.7
# Конверсия в регистрации (%)                15.4                 17.4                -2.0                      -11.7
#              Затраты (cost)               193.9                  0.0               193.9                        inf
#
# Количество дней с рекламными кампаниями: 142
# Количество дней без рекламных кампаний: 42
# Всего дней в датасете: 184
#
# ...
# Детальная статистика по каждой рекламной кампании:
# ...
#                             Визиты (ср)  Визиты (всего)  Дней  Регистрации (ср)  Регистрации (всего)  Затраты (ср)  Затраты (всего)  Конверсия (%)   CPV   CPA
# ...

# %% [markdown]
# # Анализ эффективности рекламных кампаний: выводы
#
# ## 1. Общее влияние на трафик и регистрации
#
# Проведенный анализ показывает, что запуск рекламных кампаний оказывает значительное положительное влияние на привлечение пользователей:
#
# *   **Рост трафика:** В дни проведения рекламных кампаний среднее количество **визитов увеличилось на 49%** (с 546.6 до 815.1), что дает абсолютный прирост в +268.5 визитов в день.
# *   **Рост регистраций:** Количество регистраций также выросло, хотя и менее интенсивно, чем трафик. Средний прирост составил **+31.7%** (с 95.3 до 125.6 регистраций в день).
#
# ## 2. Влияние на качество трафика (Конверсия)
#
# Несмотря на рост абсолютных показателей, наблюдается негативная тенденция в качестве привлеченного трафика:
#
# *   **Снижение конверсии:** Средняя конверсия в регистрацию в рекламные дни **снизилась на 11.7%** (с 17.4% до 15.4%).
#
# ### Возможная причина: проблема нерелевантного трафика
#
# Падение конверсии при росте трафика может указывать на классическую проблему digital-маркетинга — **привлечение нецелевой аудитории**. Вероятно, текущие настройки таргетинга или креативы привлекают много "холодных" или случайных посетителей, которые:
# - Не соответствуют портрету целевой аудитории
# - Имеют низкий интерес к продукту
# - Случайно кликнули по объявлению
#
# В результате рекламные бюджеты тратятся на большой объем низкокачественного трафика, который увеличивает общее число визитов, но "размывает" конверсию.
#
# ## 3. Сравнительная эффективность кампаний
#
# Анализ по отдельным рекламным кампаниям (utm_campaign) выявил лидеров и аутсайдеров по ключевым метрикам:
#
# ### По стоимости привлечения (CPA)
# *   **Самая эффективная (дешевая регистрация):** Кампания `advanced_algorithms_series` показывает наилучший результат по стоимости за регистрацию (**CPA = 1.29**). Это лучший показатель среди всех, что говорит о высокой релевантности аудитории или более дешевом способе привлечения.
# *   **Наименее эффективная (дорогая регистрация):** Кампания `ui_ux_design_drive` имеет самый высокий CPA (**1.82**), что делает её наименее эффективной с точки зрения окупаемости затрат на регистрацию.
#
# ### По стоимости за визит (CPV)
# *   **Самая дешевая:** Наиболее дешевый визит обеспечивает кампания `virtual_reality_workshop` (**CPV = 5.54**).
# *   **Самая дорогая:** Самый дорогой визит у кампании `women_in_tech_symposium` (**CPV = 7.42**), что в сочетании с низкой конверсией дает высокий CPA.
#
# ### По качеству трафика (Конверсия)
# *   **Лучшая конверсия:** Кампания `virtual_reality_workshop` лидирует не только по дешевизне визита, но и по качеству трафика, имея самую высокую конверсию в регистрацию (**18.0%**).
# *   **Худшая конверсия:** Кампания `women_in_tech_symposium` демонстрирует самую низкую конверсию (**13.5%**), что говорит о несоответствии аудитории или креатива целевой странице.
#
# ## 4. Рекомендации
#
# 1.  **Масштабирование успеха:** Рекомендуется увеличить бюджет на кампанию `advanced_algorithms_series`, так как она показывает самую низкую стоимость регистрации (CPA) и высокую посещаемость.
#
# 2.  **Оптимизация или остановка неэффективных кампаний:**
#     *   Кампания `women_in_tech_symposium` является самой дорогой и неэффективной. Рекомендуется провести аудит настроек таргетинга и креативов, либо приостановить кампанию.
#     *   Кампания `ui_ux_design_drive` требует оптимизации для снижения CPA.
#
# 3.  **Решение проблемы нецелевого трафика:**
#     *   **Пересмотреть портрет ЦА:** Уточнить сегменты аудитории в настройках таргетинга.
#     *   **Проанализировать креативы:** Возможно, объявления привлекают внимание не той аудитории или создают ложные ожидания.
#     *   **Оптимизировать посадочные страницы:** Убедиться, что лендинги соответствуют запросам, с которыми приходят пользователи, и содержат четкие призывы к действию.
#     *   **Настроить минус-слова:** Для контекстной рекламы важно исключить нерелевантные запросы.
